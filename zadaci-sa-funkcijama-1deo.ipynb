# %% [markdown]
# <div style="text-align:center; line-height:2; color:gray; background-color: #ccffff; height:40px">
# Раде Стојаковић, гимназија Бачка Паланка.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Задаци са функцијама - 1. део</b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info" >
#
# <strong> 1.	Написати програм који користи две функције: `podaci` (исписује име и презиме и школу и одељење) и `linije`
# да би исписао податке на следећи начин:</strong></div>
#
# ![zadaci1deo1.JPG](attachment:zadaci1deo1.JPG)

# %%
# овде пишете код за 1. задатак

# %% [markdown]
# Изменити програм тако да користећи постојеће две функције исписује податке на следећи начин
#
# ![zadaci1deo1dodatak.JPG](attachment:zadaci1deo1dodatak.JPG)

# %%
# овде пишете код за измењен 1. задатак

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <strong> 2.	Написати програм у који се уноси жељена геометријска фигура (круг или правоугаоник) и исписује површина
# и обим фигуре користећи две функције: `krug` и `pravougaonik`. Примери изгледа екрана:</strong>
#   </div>
#
#  ![zadaci1deo2.JPG](attachment:zadaci1deo2.JPG)

# %%
# овде пишете код за 2. задатак

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <strong> 3.	Написати програм у који се уноси жељена операција (сабирање, одузимање, множење или дељење) и
# исписује резултат операције. Свака операција се извршава у својој функцији. Код операције дељења, ако је
# други број 0 исписати поруку да се не може делити са нулом. На почетку програма се исписује мени са
# могућим операцијама.<br><br>
#
# Примери изгледа екрана:</strong>
#   </div>
#
# ![zadaci1deo3.JPG](attachment:zadaci1deo3.JPG)

# %%
# овде пишете код за 3. задатак

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ![pehar.JPG](attachment:pehar.JPG)
# <strong> Изменити програм тако да се након извршене операције поново појављује мени са операцијама и може се бирати операција док се не унесе 0 (нула за крај).</strong>
# </div>

# %%
# овде пишете код за измењени 3. задатак

# %% [raw]
# Име и презиме:
# одељење:

# %% [markdown]
# <div style="text-align:center; line-height:2; color:gray; background-color: #F8F8F8; height:40px">
# Гимназија "20. октобар" Бачка Паланка.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger" style="font-size:1.2em; color:#003366">
#
# Jupyter свесци промените име тако што ћете кликнути на име свеске у горњем делу екрана и у прозору који се појави имену свеске дописати своје име и презиме и кликнути на дугме **`Rename`**</div>
#
# <img src="attachment:rename%20notebook.JPG" width="500">

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Задаци са функцијама - 2. део</b>
# </div>

# %% [markdown]
# 1. **варијанта 1 (лакша)**: У **`main()`** функцији се бирају опција сабирања бројева од 10 до 100 или од 100 до 1000. У функцијама **`zbir_do_100()`** и **`zbir_do_1000()`** се уносе два броја и корисник уноси збир. Ако је уписан тачан збир исписује се порука **`Tačno,`**а ако није исписује се порука **`Netačno`** и тачан збир.
#
#    **варијанта 2 (мало тежа)**: У **`main()`** функцији се бирају опција сабирања бројева од 10 до 100 или од 100 до 1000. У функцијама **`zbir_do_100()`** и **`zbir_do_1000()`** генеришу се **`n`** пута 2 броја и корисник уноси збир. Ако је уписан тачан збир исписује се порука **`Tačno`**, а ако није исписује се порука **`Netačno`** и тачан збир.
#
#   **додатак***: исписати број тачних и број погрешних одговора и проценат успешности

# %%
# покретањем ове ћелије можете видети начин функционисања програма
# кликните на ову ћелију и покрените је (ctrl + enter или дугме Run у горњем менију)
from IPython.display import HTML

HTML("""
<video width="800" controls>
  <source src="http://rade.gimnazijabp.edu.rs/zadaci_sa_funkcijama2deo_1.mp4" type="video/mp4">
</video>
""")

# %%
# овде пишете код за 1. задатак

# %% [markdown]
# 2.  **варијанта 1 (лакша)**: У **`main`** функцији се бира уношење изостанака или оцена са матурског испита. У функцији **`izostanci()`** уноси се број неоправданих изостанака и исписује оцена из владања по скали приказаној у табели. У функцији **`maturski()`** се уносе оцене из српског, изборног и матурског рада. Исписати просечну оцену. Ако ученик има 1 из неког дела матурског испита тада је просечна оцена 1.00
#
#     **варијанта 2 (мало тежа)**: У **`main`** функцији се бира уношење изостанака или оцена са матурског испита. У функцији **`izostanci()`** уноси се број неоправданих изостанака по недељама док се не унесе **`-1`**. Исписује се укупан број изостанака и на основу њега оцена из владања.<br> У функцији **`maturski()`** се уносе оцене из српског, изборног и матурског рада. Исписати просечну оцену и успех (одличан, врлодобар...). Ако ученик има 1 из неког дела матурског испита тада је просечна оцена 1.00
#
# |изостанака|оцена|
# |----------|-----|
# |0 - 4|5|
# |6 - 8|4|
# |9 - 16|3|
# |17 - 25|2|
# |>25|1|

# %%
# покретањем ове ћелије можете видети начин функционисања програма
# кликните на ову ћелију и покрените је (ctrl + enter или дугме Run у горњем менију)
from IPython.display import HTML

HTML("""
<video width="800" controls>
  <source src="http://rade.gimnazijabp.edu.rs/zadaci_sa_funkcijama2deo_2.mp4" type="video/mp4">
</video>
""")

# %%
# овде пишете код за 2. задатак

# %% [raw]
# Име и презиме:
# Одељење:
